# %%
# drawing utils
# %matplotlib notebook
from matplotlib import pyplot as plt
import matplotlib.ticker

# math utils
import numpy as np

# statistics utils
import pandas as pd

# %%
# read data from files

file = './Spectra.dat'

# with open(file, 'r', encoding='utf-8') as f:
#     sdata = f.read()

sdata = np.loadtxt(file)

# %%
# fig, ax = plt.subplots()

# plt.imshow(sdata)

# %%
test1 = sdata[:, 1200]
plt.plot(test1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
test1ft = np.fft.fft(test1)
plt.plot(test1ft)
plt.show()
# Out:
# /home/a304/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
