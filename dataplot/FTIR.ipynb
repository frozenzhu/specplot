# %%
# drawing utils
# %matplotlib notebook
from matplotlib import pyplot as plt
import matplotlib.ticker

# math utils
import numpy as np

# statistics utils
import pandas as pd

# %%
# read data from files

file = '../PT1-FTIR/THF.CSV'

# with open(file, 'r', encoding='utf-8') as f:
#     sdata = f.read()

sdata = np.loadtxt(file, delimiter=',')

# %%
# parse data

xs = sdata[:,0]
ys = sdata[:,1]

# effx = min([(len(i) - 1) if ('.' in i) else len(i) for i in xs])
# effy = min([(len(i) - 1) if ('.' in i) else len(i) for i in ys])
effx = 'na'
effy = 'na'


ptemp = '''Data parsed. 
Found {lenx} x values, {leny} y values.
Estimated effective figures: x: {effx}, y: {effy}
First 5 rows are:'''

print(ptemp.format(lenx=len(xs), leny=len(ys), effx=effx, effy=effy))
for i in range(5):
    print(xs[i], ys[i])


# print(s)
# Out:
# Data parsed.
# Found 3199 x values, 3199 y values.
# Estimated effective figures: x: na, y: na
# First 5 rows are:
# 1129.647 1.618965
# 1130.129 1.61661
# 1130.611 1.613665
# 1131.093 1.610343
# 1131.576 1.606849

# %%
# set plot details

fig, ax = plt.subplots()

ax.plot(xs, ys, linewidth=1, label='THF', color='red')

ax.set(xlabel='Wavenumber (cm-1)', 
       ylabel='Absorption',
       title='FTIR Spectrum')

ax.legend()
# ax.set(ylim=(0.1,0.7),xlim=(800, 1600))

# ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(50)) 
# ax.xaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter('%1.1f')) 
# ax.yaxis.set_major_locator(matplotlib.ticker.MultipleLocator(0.1)) 
# ax.yaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter('%1.2f')) 

# for FTIR, it is common to invert x axis (wavenumbers)
ax.invert_xaxis()

ax.grid()

# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="943">

# %%
# read data from files

file = '../PT1-FTIR/THF-PT1.CSV'

# with open(file, 'r', encoding='utf-8') as f:
#     sdata = f.read()

sdata = np.loadtxt(file, delimiter=',')

# %%
# parse data

xs = sdata[:,0]
ys = sdata[:,1]

# effx = min([(len(i) - 1) if ('.' in i) else len(i) for i in xs])
# effy = min([(len(i) - 1) if ('.' in i) else len(i) for i in ys])
effx = 'na'
effy = 'na'


ptemp = '''Data parsed. 
Found {lenx} x values, {leny} y values.
Estimated effective figures: x: {effx}, y: {effy}
First 5 rows are:'''

print(ptemp.format(lenx=len(xs), leny=len(ys), effx=effx, effy=effy))
for i in range(5):
    print(xs[i], ys[i])


# print(s)
# Out:
# Data parsed.
# Found 3199 x values, 3199 y values.
# Estimated effective figures: x: na, y: na
# First 5 rows are:
# 1129.647 1.039507
# 1130.129 1.039295
# 1130.611 1.039069
# 1131.093 1.038748
# 1131.576 1.038291

# %%
ax.plot(xs, ys, linewidth=1, label='THF Solution', color='black')

# %%
ax.legend()
